# %%
import numpy as np
import numpy_financial as npf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import random

# %%
monthly = 8000
annual = monthly * 12
years = 7
rate = 0.04

# %%
settle_npv = npf.npv(
pv
# Out:
# 95849.51053843716

# %%
annual * 7
# Out:
# 672000
